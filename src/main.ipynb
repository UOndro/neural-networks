# %%
from datetime import datetime
from tensorflow import keras
from src.data.load_data import train_X, train_y, validation_X, validation_y, test_X, test_y
from src.models.model import model
from src.models.predict import predict, avg_precision
from src.models.train import fit
# Out:
# /home/ounger/university/zs-19/neural-networks/src/data/load_data.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   names=['user_id', 'movie_id', 'rating', 'timestamp'])

# %%
# %load_ext tensorboard
# %tensorboard --logdir ../data/logs --bind_all
model.fit(
    x=train_X,
    y=train_y,
    batch_size=100,
    epochs=30,
    validation_data=(validation_X, validation_y))
# Out:
# Launching TensorBoard...
# Train on 4081 samples, validate on 1575 samples
# Epoch 1/30
# 4081/4081 [==============================] - 13s 3ms/sample - loss: 8.0776 - val_loss: 7.6846
# Epoch 2/30
# 4081/4081 [==============================] - 11s 3ms/sample - loss: 7.3271 - val_loss: 7.7789
# Epoch 3/30
# 4081/4081 [==============================] - 14s 3ms/sample - loss: 7.1729 - val_loss: 7.8066
# Epoch 4/30
# 4081/4081 [==============================] - 13s 3ms/sample - loss: 7.1250 - val_loss: 7.8454
# Epoch 5/30
# 4081/4081 [==============================] - 13s 3ms/sample - loss: 7.0923 - val_loss: 7.8925
# Epoch 6/30
# 4081/4081 [==============================] - 11s 3ms/sample - loss: 7.0728 - val_loss: 7.9519
# Epoch 7/30
# 4081/4081 [==============================] - 10s 2ms/sample - loss: 7.0581 - val_loss: 7.9710
# Epoch 8/30
# 4081/4081 [==============================] - 10s 2ms/sample - loss: 7.0499 - val_loss: 7.9761
# Epoch 9/30
# 4081/4081 [==============================] - 9s 2ms/sample - loss: 7.0412 - val_loss: 8.0099
# Epoch 10/30
# 4081/4081 [==============================] - 9s 2ms/sample - loss: 7.0305 - val_loss: 8.0672
# Epoch 11/30
# 4081/4081 [==============================] - 10s 3ms/sample - loss: 7.0189 - val_loss: 8.0523
# Epoch 12/30
# 4081/4081 [==============================] - 10s 3ms/sample - loss: 7.0050 - val_loss: 8.0590
# Epoch 13/30
# 4081/4081 [==============================] - 13s 3ms/sample - loss: 6.9831 - val_loss: 8.0470
# Epoch 14/30
# 4081/4081 [==============================] - 12s 3ms/sample - loss: 6.9559 - val_loss: 8.1052
# Epoch 15/30
# 4081/4081 [==============================] - 13s 3ms/sample - loss: 6.9306 - val_loss: 8.0624
# Epoch 16/30
# 4081/4081 [==============================] - 13s 3ms/sample - loss: 6.8931 - val_loss: 8.0564
# Epoch 17/30
# 4081/4081 [==============================] - 12s 3ms/sample - loss: 6.8566 - val_loss: 8.0366
# Epoch 18/30
# 4081/4081 [==============================] - 12s 3ms/sample - loss: 6.9560 - val_loss: 8.2928
# Epoch 19/30
# 4081/4081 [==============================] - 12s 3ms/sample - loss: 6.8921 - val_loss: 8.2025
# Epoch 20/30
# 4081/4081 [==============================] - 12s 3ms/sample - loss: 6.8380 - val_loss: 8.2192
# Epoch 21/30
# 4081/4081 [==============================] - 12s 3ms/sample - loss: 6.8053 - val_loss: 8.2342
# Epoch 22/30
# 4081/4081 [==============================] - 11s 3ms/sample - loss: 6.7703 - val_loss: 8.1859
# Epoch 23/30
# 4081/4081 [==============================] - 11s 3ms/sample - loss: 6.7365 - val_loss: 8.1749
# Epoch 24/30
# 4081/4081 [==============================] - 9s 2ms/sample - loss: 6.7068 - val_loss: 8.1637
# Epoch 25/30
# 4081/4081 [==============================] - 10s 2ms/sample - loss: 6.6789 - val_loss: 8.2249
# Epoch 26/30
# 4081/4081 [==============================] - 10s 2ms/sample - loss: 6.6530 - val_loss: 8.1686
# Epoch 27/30
# 4081/4081 [==============================] - 12s 3ms/sample - loss: 6.6398 - val_loss: 8.2803
# Epoch 28/30
# 4081/4081 [==============================] - 9s 2ms/sample - loss: 6.6184 - val_loss: 8.1872
# Epoch 29/30
# 4081/4081 [==============================] - 9s 2ms/sample - loss: 6.5865 - val_loss: 8.2290
# Epoch 30/30
# 4081/4081 [==============================] - 9s 2ms/sample - loss: 6.5539 - val_loss: 8.2288

# %%
y_pred = predict(model, test_X)

# %%
print(avg_precision(test_y, y_pred))
